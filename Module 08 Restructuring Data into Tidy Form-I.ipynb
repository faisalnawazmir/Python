# %% [markdown]
# # Module 8: Restructuring Data into Tidy Form

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Tidying variable values as column names with stack

# %%
# We read csv file with column0 (representing the state) declared as the index

state_fruit = pd.read_csv('data/state_fruit.csv', index_col=0)

print('Weight of different fruits by state')
state_fruit
# Out:
# Weight of different fruits by state
#          Apple  Orange  Banana
# Texas       12      10      40
# Arizona      9       7      12
# Florida      0      14     190

# %% [markdown]
# # Principles of Tidy Data
#
# * Each variable forms a column
# * Each observation forms a row
# * Each observational unit forms a table

# %%
# The values in the above data are fruit weights
# The fruit (name) and State (name) are just identifiers
# We can create a single column for weights, with two grouping columns: State, and fruit

# We use .stack method
state_fruit.stack()
# Out:
# Texas    Apple      12
#          Orange     10
#          Banana     40
# Arizona  Apple       9
#          Orange      7
#          Banana     12
# Florida  Apple       0
#          Orange     14
#          Banana    190
# dtype: int64

# %% [raw]
# The above output is NOT really in tidy format (each variable forms a column, and each robservation forms a row).
# The state name appears once for every three rows instead of appearing in each row.

# %%
# We use .reset-index method to make state name appear in each row

state_fruit_tidy = state_fruit.stack().reset_index()
state_fruit_tidy
# Out:
#    level_0 level_1    0
# 0    Texas   Apple   12
# 1    Texas  Orange   10
# 2    Texas  Banana   40
# 3  Arizona   Apple    9
# 4  Arizona  Orange    7
# 5  Arizona  Banana   12
# 6  Florida   Apple    0
# 7  Florida  Orange   14
# 8  Florida  Banana  190

# %%
# level_0 and level_1 are not appropriate variable names, and '0' is not a valid variable name.
# Therefore, we assign new variable names as follows:

state_fruit_tidy.columns = ['state', 'fruit', 'weight']
state_fruit_tidy
# Out:
#      state   fruit  weight
# 0    Texas   Apple      12
# 1    Texas  Orange      10
# 2    Texas  Banana      40
# 3  Arizona   Apple       9
# 4  Arizona  Orange       7
# 5  Arizona  Banana      12
# 6  Florida   Apple       0
# 7  Florida  Orange      14
# 8  Florida  Banana     190

# %% [markdown]
# # Tidying variable values as column names with melt

# %% [raw]
# The .melt method allows to distinguish between column names that you want NOT to reshape (id_vars), and
# the column names that you want to reshape into a single column (value_vars)
#
# The names of the value_vars are stacked in a single column whose name is supplied by the user as 'variable'
# Finally the user also supplies a value-name for the column that stores data
#
# SEE Example BELOW (state_fruit2 data):
# id_vars    ='state'
# value_vars =['Apple', 'Orange', 'Banana']
# variable   = 'fruit'
# value_name = 'Weight'

# %%
state_fruit2 = pd.read_csv('data/state_fruit2.csv')
state_fruit2
# Out:
#      State  Apple  Orange  Banana
# 0    Texas     12      10      40
# 1  Arizona      9       7      12
# 2  Florida      0      14     190

# %%
# The following snippet only uses two parameter for melt method: id_vars and value_vars
# as a result the column containing 'apple', orange etc does not have a specific name, its just labelled 'variable'
# also the column containing values of weight is just labeled 'value'

state_fruit2.melt(id_vars=['State'],
                 value_vars=['Apple', 'Orange', 'Banana'])
# Out:
#      State variable  value
# 0    Texas    Apple     12
# 1  Arizona    Apple      9
# 2  Florida    Apple      0
# 3    Texas   Orange     10
# 4  Arizona   Orange      7
# 5  Florida   Orange     14
# 6    Texas   Banana     40
# 7  Arizona   Banana     12
# 8  Florida   Banana    190

# %%
# In the above, the .melt method refers to transformed former columns names(Apple, Orange, Banana) as 'variable'
# and corresponding values as 'value'

# To rename these two columns, .melt method accepts two additional parameters 'var_name' and 'value_name'

state_fruit2.melt(id_vars=['State'],
                 value_vars=['Apple', 'Orange', 'Banana'],
                 var_name='Fruit',
                 value_name='Weight')
# Out:
#      State   Fruit  Weight
# 0    Texas   Apple      12
# 1  Arizona   Apple       9
# 2  Florida   Apple       0
# 3    Texas  Orange      10
# 4  Arizona  Orange       7
# 5  Florida  Orange      14
# 6    Texas  Banana      40
# 7  Arizona  Banana      12
# 8  Florida  Banana     190

# %%
# Sometimes you have a lots of variables to melt, and you want to specify only the id-vars
# the .melt method will in that case be passewd only one parameter i.e id_vars. If id_vars is a single column, 
# you could just pass it as string instead of a list, as shwon below:

state_fruit2.melt(id_vars='State')
# Out:
#      State variable  value
# 0    Texas    Apple     12
# 1  Arizona    Apple      9
# 2  Florida    Apple      0
# 3    Texas   Orange     10
# 4  Arizona   Orange      7
# 5  Florida   Orange     14
# 6    Texas   Banana     40
# 7  Arizona   Banana     12
# 8  Florida   Banana    190

# %% [raw]
# In the above case, you get the same result as before. Note that melt correctly picked up value_vars.
# However, also note that the in this case the last two columns do not have meaningful, descriptive labels.
# For this you have to supply var_name and value_name, as shown in an earlier step.

# %% [markdown]
# # Stacking multiple groups of variables simultaneously
# ## wide-to-long function

# %%
df = pd.read_csv('data/stackme.csv')
df
# Out:
#   State Country    a1   b2   Test  d  e
# 0    TX      US  0.45  0.3  Test1  2  6
# 1    MA      US  0.03  1.2  Test2  9  7
# 2    ON     CAN  0.70  4.2  Test3  4  2

# %% [raw]
# Before we can use the wide-to-long function, we need to rename variable to ensure that their names
# conform to uniform format (a1, a2, d, e, do not follow a uniform namming convention).
#
# We use dictionary for renaming variables

# %%
df2 = df.rename(columns = {'a1':'group1_a', 'b2':'group1_b',
                           'd':'group2_a', 'e':'group2_b'})
df2
# Out:
#   State Country  group1_a  group1_b   Test  group2_a  group2_b
# 0    TX      US      0.45       0.3  Test1         2         6
# 1    MA      US      0.03       1.2  Test2         9         7
# 2    ON     CAN      0.70       4.2  Test3         4         2

# %% [raw]
# The above data is in wide format (many variables which measure similar things: group1_a, group1_b, group2_a, group2_b)
# We would like to convert it into long format with similar variables stacked into columns, and with observations duly labeled.
#
# We specify the following:
#
# index 'i' for list of id variables
#
# index 'j' for labels that will identify observations
#
# 'suffix' for observation labels to be extracted with regular expression from former column names
#          (here the suffix is '.+' which will extract numeric or characters e.g 'a', 'b' at the end of
#          names of former variable such as group1_a group1_b etc
#
# 'sep' a separator for suffix. In this case the separater is '_' after which teh suffix 'a' or 'b' will be extracted
#       to be used as label for observations
#
# 'stubnames' the variable names for storing values (here group1, group2).

# %%
pd.wide_to_long(df2, 
                stubnames=['group1', 'group2'], 
                i=['State', 'Country', 'Test'], 
                j='Label', 
                suffix='.+', 
                sep='_')
# Out:
#                            group1  group2
# State Country Test  Label
# TX    US      Test1 a        0.45       2
#                     b        0.30       6
# MA    US      Test2 a        0.03       9
#                     b        1.20       7
# ON    CAN     Test3 a        0.70       4
#                     b        4.20       2

# %% [markdown]
# # Inverting stacked data

# %% [raw]
# In the example below we use college data, we use the institution name (INSTNM) as index, and stack the columns providing percentages of various races (UGDS_WHITE, UGDS_WHITE, etc) with rows giving race labels (i.e. former col names).
#
# First we need to select all the race columns (UGDS_WHITE, UGDS_WHITE, etc), which we do by passing a usecols= parameter to pd.read_csv(). We could assign a list to the usecols= parameter. Alternatively, we could write a function that generates the required column names dynamically. We choose the latter.

# %%
# defining the  column generator function
usecol_func = lambda x: 'UGDS_' in x or x == 'INSTNM'

# reading selected columns from the college dataFrame
college = pd.read_csv('data/college.csv', 
                          index_col='INSTNM', 
                          usecols=usecol_func)
college.head()
# Out:
#                                      UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Alabama A & M University                 0.0333      0.9353     0.0055
# University of Alabama at Birmingham      0.5922      0.2600     0.0283
# Amridge University                       0.2990      0.4192     0.0069
# University of Alabama in Huntsville      0.6988      0.1255     0.0382
# Alabama State University                 0.0158      0.9208     0.0121
#
#                                      UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Alabama A & M University                 0.0019     0.0024     0.0019
# University of Alabama at Birmingham      0.0518     0.0022     0.0007
# Amridge University                       0.0034     0.0000     0.0000
# University of Alabama in Huntsville      0.0376     0.0143     0.0002
# Alabama State University                 0.0019     0.0010     0.0006
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# ...

# %%
# We use .stack method to stack all the racial proportion columns by INSTNM and race
# In other words, we are converting the data into long format

college_stacked = college.stack()
college_stacked.head(18)
# Out:
# INSTNM
# Alabama A & M University             UGDS_WHITE    0.0333
#                                      UGDS_BLACK    0.9353
#                                      UGDS_HISP     0.0055
#                                      UGDS_ASIAN    0.0019
#                                      UGDS_AIAN     0.0024
#                                      UGDS_NHPI     0.0019
#                                      UGDS_2MOR     0.0000
#                                      UGDS_NRA      0.0059
#                                      UGDS_UNKN     0.0138
# University of Alabama at Birmingham  UGDS_WHITE    0.5922
#                                      UGDS_BLACK    0.2600
#                                      UGDS_HISP     0.0283
#                                      UGDS_ASIAN    0.0518
#                                      UGDS_AIAN     0.0022
#                                      UGDS_NHPI     0.0007
#                                      UGDS_2MOR     0.0368
# ...

# %%
# We can reverse the operation by unstack, and get the data back in the original format
# Note, particularly, how the .unstack method converst row labels into separate columns names

college_stacked.unstack().head()
# Out:
#                                      UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Alabama A & M University                 0.0333      0.9353     0.0055
# University of Alabama at Birmingham      0.5922      0.2600     0.0283
# Amridge University                       0.2990      0.4192     0.0069
# University of Alabama in Huntsville      0.6988      0.1255     0.0382
# Alabama State University                 0.0158      0.9208     0.0121
#
#                                      UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Alabama A & M University                 0.0019     0.0024     0.0019
# University of Alabama at Birmingham      0.0518     0.0022     0.0007
# Amridge University                       0.0034     0.0000     0.0000
# University of Alabama in Huntsville      0.0376     0.0143     0.0002
# Alabama State University                 0.0019     0.0010     0.0006
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# ...

# %% [markdown]
# # Using melt to create long data

# %%
college2 = pd.read_csv('data/college.csv', 
                      usecols=usecol_func)
college2.head()
# Out:
#                                 INSTNM  UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# 0             Alabama A & M University      0.0333      0.9353     0.0055
# 1  University of Alabama at Birmingham      0.5922      0.2600     0.0283
# 2                   Amridge University      0.2990      0.4192     0.0069
# 3  University of Alabama in Huntsville      0.6988      0.1255     0.0382
# 4             Alabama State University      0.0158      0.9208     0.0121
#
#    UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# 0      0.0019     0.0024     0.0019     0.0000    0.0059     0.0138
# 1      0.0518     0.0022     0.0007     0.0368    0.0179     0.0100
# 2      0.0034     0.0000     0.0000     0.0000    0.0000     0.2715
# 3      0.0376     0.0143     0.0002     0.0172    0.0332     0.0350
# 4      0.0019     0.0010     0.0006     0.0098    0.0243     0.0137

# %% [raw]
# Specifying var_name (='Race') to specify name of column for storing the race labels.
# Also specifying the value_name (='Percentage') for name of variable for storing race proportion.
#
# Note that we are not specifying value_vars parameter, which provides a list of columns whose names would be used as row labels. So by default the names of all columns in the dataFrame, except the index variable (INSTNM), will be used as row labels when the data is converted to long format by the melt method.

# %%
# melting college data

college_melted = college2.melt(id_vars='INSTNM', 
                               var_name='Race',
                               value_name='Percentage')
college_melted.head()
# Out:
#                                 INSTNM        Race  Percentage
# 0             Alabama A & M University  UGDS_WHITE      0.0333
# 1  University of Alabama at Birmingham  UGDS_WHITE      0.5922
# 2                   Amridge University  UGDS_WHITE      0.2990
# 3  University of Alabama in Huntsville  UGDS_WHITE      0.6988
# 4             Alabama State University  UGDS_WHITE      0.0158

# %% [raw]
# Next we want to convert the data back into wide format by undoing melt with pivot.
#
# To accomplish this we have to read row-labels and make columns names out of them. We do thsi by specifying the parameter columns (='Race') to indicate that the needed row labels can be read from the 'Race' column in the dataFrame.
#
# Also, we specify the parameter values (='Percentage') to indicate that this column has the data values.

# %%
melted_inv = college_melted.pivot(index='INSTNM',
                                  columns='Race',
                                  values='Percentage')
melted_inv.head()
# Out:
# Race                                                UGDS_2MOR  UGDS_AIAN  \
# INSTNM
# A & W Healthcare Educators                             0.0000        0.0
# A T Still University of Health Sciences                   NaN        NaN
# ABC Beauty Academy                                     0.0000        0.0
# ABC Beauty College Inc                                 0.0000        0.0
# AI Miami International University of Art and De...     0.0018        0.0
#
# Race                                                UGDS_ASIAN  UGDS_BLACK  \
# INSTNM
# A & W Healthcare Educators                              0.0000      0.9750
# A T Still University of Health Sciences                    NaN         NaN
# ABC Beauty Academy                                      0.9333      0.0333
# ABC Beauty College Inc                                  0.0000      0.6579
# AI Miami International University of Art and De...      0.0018      0.0198
#
# ...

# %% [raw]
# Note that both the row index (INSTNM) and the column index (Race) are sorted differently compared to the original college2 dataFrame. To have rows and columns in the same order as in the college2 dataset we have to simultaneously read the row and column names from the college2 dataFrame. This is done with the .loc[] indexer, with rows and cols specified simulataneously.
#
# The resulting dadaFrame i.e. college2_replication is teh replication of the college2 dataFrame.

# %%
college2_replication = melted_inv.loc[college2['INSTNM'], 
                                      college2.columns[1:]]\
                                         .reset_index()
# college2.equals(college2_replication)

college2_replication
# Out:
#                                                  INSTNM  UGDS_WHITE  \
# 0                              Alabama A & M University      0.0333
# 1                   University of Alabama at Birmingham      0.5922
# 2                                    Amridge University      0.2990
# 3                   University of Alabama in Huntsville      0.6988
# 4                              Alabama State University      0.0158
# 5                             The University of Alabama      0.7825
# 6                     Central Alabama Community College      0.7255
# 7                               Athens State University      0.7823
# 8                       Auburn University at Montgomery      0.5328
# 9                                     Auburn University      0.8507
# 10                          Birmingham Southern College      0.7983
# 11               Chattahoochee Valley Community College      0.4661
# 12                            Concordia College Alabama      0.0280
# ...

# %% [markdown]
# ## We could also use .unstack(0) method to unstack

# %% [raw]
# Note that .stack method on college data creates two index levels -- INSTNM (level0) and unnamed level(1) that is based on race. Here level(1) is the innermost level, and pandas default is to use this level as column names while unstacking. So the column names in unstacked college data would be the race names [this is also level -1, i.e. the last level or inner-most level]
#
# If we do not want to use pandas default setting (unstack by innermost level) we could specify that we want to unstack by outer-most level(0), which would be the INSTNM.
#
# So in this case, the values of INSTNM variable would become column names, and the rows would remain the race labels.

# %%
college.stack().unstack(0)
# Out:
# INSTNM      Alabama A & M University  University of Alabama at Birmingham  \
# UGDS_WHITE                    0.0333                               0.5922
# UGDS_BLACK                    0.9353                               0.2600
# UGDS_HISP                     0.0055                               0.0283
# UGDS_ASIAN                    0.0019                               0.0518
# UGDS_AIAN                     0.0024                               0.0022
# UGDS_NHPI                     0.0019                               0.0007
# UGDS_2MOR                     0.0000                               0.0368
# UGDS_NRA                      0.0059                               0.0179
# UGDS_UNKN                     0.0138                               0.0100
#
# INSTNM      Amridge University  University of Alabama in Huntsville  \
# UGDS_WHITE              0.2990                               0.6988
# UGDS_BLACK              0.4192                               0.1255
# ...

# %% [raw]
# Note that the above data is simply college dataFrame transposed.
#
# This can be accomplished much more easily by simply transposing the college dataFrame as shown below.

# %%
college.T
# Out:
# INSTNM      Alabama A & M University  University of Alabama at Birmingham  \
# UGDS_WHITE                    0.0333                               0.5922
# UGDS_BLACK                    0.9353                               0.2600
# UGDS_HISP                     0.0055                               0.0283
# UGDS_ASIAN                    0.0019                               0.0518
# UGDS_AIAN                     0.0024                               0.0022
# UGDS_NHPI                     0.0019                               0.0007
# UGDS_2MOR                     0.0000                               0.0368
# UGDS_NRA                      0.0059                               0.0179
# UGDS_UNKN                     0.0138                               0.0100
#
# INSTNM      Amridge University  University of Alabama in Huntsville  \
# UGDS_WHITE              0.2990                               0.6988
# UGDS_BLACK              0.4192                               0.1255
# ...

# %% [markdown]
# # Unstacking after a groupby aggregation

# %%
employee = pd.read_csv('data/employee.csv')

# %% [raw]
# Using groupby method with multiple grouping variables creates index consisting of multiple columns, so unstacking a data resulting from such an operation may be extremely useful.
#
# However, it may not give us the format in which we  want to presnt the results. We can control the operation of unstack method by specifying the which index we want to be unstacked.
#
# In the groupby operation below we aggregate BASE_SALARY(aggregation variable) by RACE(grouping variable), and our aggregation function is the mean.

# %%
employee.groupby('RACE')['BASE_SALARY'].mean().astype(int)
# Out:
# RACE
# American Indian or Alaskan Native    60272
# Asian/Pacific Islander               61660
# Black or African American            50137
# Hispanic/Latino                      52345
# Others                               51278
# White                                64419
# Name: BASE_SALARY, dtype: int32

# %% [raw]
# Now let's try to specify two grouping variables (RACE and GENDER) for the groupby operation. In this case the .groupby method produces a two-level index composed on unique combinations of RACE and GENDER, either of which could be used for unstacking the data.

# %%
agg = employee.groupby(['RACE', 'GENDER'])['BASE_SALARY'].mean().astype(int)
agg
# Out:
# RACE                               GENDER
# American Indian or Alaskan Native  Female    60238
#                                    Male      60305
# Asian/Pacific Islander             Female    63226
#                                    Male      61033
# Black or African American          Female    48915
#                                    Male      51082
# Hispanic/Latino                    Female    46503
#                                    Male      54782
# Others                             Female    63785
#                                    Male      38771
# White                              Female    66793
#                                    Male      63940
# Name: BASE_SALARY, dtype: int32

# %% [raw]
# Suppose we want to make comparaison of mean salaray for each race by gender. It would therefore make more sense if we let rows represent the races, and we created to gender columns (Female, Male).
#
# Hence we need to unstack the data by using the gender level index.

# %%
# unstacking data using gender level index

agg.unstack('GENDER')
# Out:
# GENDER                             Female   Male
# RACE
# American Indian or Alaskan Native   60238  60305
# Asian/Pacific Islander              63226  61033
# Black or African American           48915  51082
# Hispanic/Latino                     46503  54782
# Others                              63785  38771
# White                               66793  63940

# %%
# Alternatively, we could unstacked the aggregated data by race level index.

agg.unstack('RACE')
# Out:
# RACE    American Indian or Alaskan Native  Asian/Pacific Islander  \
# GENDER
# Female                              60238                   63226
# Male                                60305                   61033
#
# RACE    Black or African American  Hispanic/Latino  Others  White
# GENDER
# Female                      48915            46503   63785  66793
# Male                        51082            54782   38771  63940

# %% [markdown]
# ## many aggregation functions

# %%
agg2 = employee.groupby(['RACE', 'GENDER'])['BASE_SALARY'].agg(['mean', 'max', 'min']).astype(int)
agg2
# Out:
#                                            mean     max    min
# RACE                              GENDER
# American Indian or Alaskan Native Female  60238   98536  26125
#                                   Male    60305   81239  26125
# Asian/Pacific Islander            Female  63226  130416  26125
#                                   Male    61033  163228  27914
# Black or African American         Female  48915  150416  24960
#                                   Male    51082  275000  26125
# Hispanic/Latino                   Female  46503  126115  26125
#                                   Male    54782  165216  26104
# Others                            Female  63785   63785  63785
#                                   Male    38771   38771  38771
# White                             Female  66793  178331  27955
#                                   Male    63940  210588  26125

# %%
agg2.unstack('GENDER')
# Out:
#                                     mean            max            min
# GENDER                            Female   Male  Female    Male Female   Male
# RACE
# American Indian or Alaskan Native  60238  60305   98536   81239  26125  26125
# Asian/Pacific Islander             63226  61033  130416  163228  26125  27914
# Black or African American          48915  51082  150416  275000  24960  26125
# Hispanic/Latino                    46503  54782  126115  165216  26125  26104
# Others                             63785  38771   63785   38771  63785  38771
# White                              66793  63940  178331  210588  27955  26125

# %% [markdown]
# # Replicating pivot_table with a groupby aggregation

# %%
flights = pd.read_csv('data/flights.csv')
flights.head()

# %%
fp = flights.pivot_table(index='AIRLINE', 
                         columns='ORG_AIR', 
                         values='CANCELLED', 
                         aggfunc='sum',
                         fill_value=0).round(2)
fp.head()

# %%
fg = flights.groupby(['AIRLINE', 'ORG_AIR'])['CANCELLED'].sum()
fg.head()

# %%
fg_unstack = fg.unstack('ORG_AIR', fill_value=0)
fg_unstack.head()

# %%
fp.equals(fg_unstack)

# %% [markdown]
# ## There's more...

# %%
fp2 = flights.pivot_table(index=['AIRLINE', 'MONTH'],
                          columns=['ORG_AIR', 'CANCELLED'],
                          values=['DEP_DELAY', 'DIST'],
                          aggfunc=[np.mean, np.sum],
                          fill_value=0)
fp2.head()

# %%
flights.groupby(['AIRLINE', 'MONTH', 'ORG_AIR', 'CANCELLED'])['DEP_DELAY', 'DIST'] \
       .agg(['mean', 'sum']) \
       .unstack(['ORG_AIR', 'CANCELLED'], fill_value=0) \
       .swaplevel(0, 1, axis='columns') \
       .head()

# %% [markdown]
# # Renaming axis levels for easy reshaping

# %%
college = pd.read_csv('data/college.csv')

# %%
cg = college.groupby(['STABBR', 'RELAFFIL'])['UGDS', 'SATMTMID'] \
            .agg(['count', 'min', 'max']).head(6)

# %%
cg

# %%
cg = cg.rename_axis(['AGG_COLS', 'AGG_FUNCS'], axis='columns')
cg

# %%
cg.stack('AGG_FUNCS').head()

# %%
cg.stack('AGG_FUNCS').swaplevel('AGG_FUNCS', 'STABBR', axis='index').head()

# %%
cg.stack('AGG_FUNCS') \
  .swaplevel('AGG_FUNCS', 'STABBR', axis='index') \
  .sort_index(level='RELAFFIL', axis='index') \
  .sort_index(level='AGG_COLS', axis='columns').head(6)

# %%
cg.stack('AGG_FUNCS').unstack(['RELAFFIL', 'STABBR'])

# %%
cg.stack(['AGG_FUNCS', 'AGG_COLS']).head(12)

# %% [markdown]
# # There's more...

# %%
cg.rename_axis([None, None], axis='index').rename_axis([None, None], axis='columns')
