# %% [raw]
# # Module 7: Grouping for Aggregation-II

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Customizing aggregating functions with \*args and \*\*kwargs

# %%
college = pd.read_csv('data/college.csv')
grouped = college.groupby(['STABBR', 'RELAFFIL'])

# %%
import inspect
inspect.signature(grouped.agg)
# Out:
# <Signature (arg, *args, **kwargs)>

# %%
def pct_between(s, low, high):
    return s.between(low, high).mean()

# %%
college.groupby(['STABBR', 'RELAFFIL'])['UGDS'].agg(pct_between, 1000, 10000).head(9)
# Out:
# STABBR  RELAFFIL
# AK      0           0.428571
#         1           0.000000
# AL      0           0.458333
#         1           0.375000
# AR      0           0.397059
#         1           0.166667
# AS      0           1.000000
# AZ      0           0.233871
#         1           0.111111
# Name: UGDS, dtype: float64

# %% [markdown]
# ## Making the arguments more explicit

# %%
college.groupby(['STABBR', 'RELAFFIL'])['UGDS'].agg(pct_between, high=10000, low=1000).head(9)
# Out:
# STABBR  RELAFFIL
# AK      0           0.428571
#         1           0.000000
# AL      0           0.458333
#         1           0.375000
# AR      0           0.397059
#         1           0.166667
# AS      0           1.000000
# AZ      0           0.233871
#         1           0.111111
# Name: UGDS, dtype: float64

# %% [markdown]
# # Examining a groupby object

# %%
college = pd.read_csv('data/college.csv')
grouped = college.groupby(['STABBR', 'RELAFFIL'])
type(grouped)
# Out:
# pandas.core.groupby.groupby.DataFrameGroupBy

# %%
college_grp =college[['INSTNM', 'STABBR', 'RELAFFIL']]
college_grp.head(15)
# Out:
#                                     INSTNM STABBR  RELAFFIL
# 0                 Alabama A & M University     AL         0
# 1      University of Alabama at Birmingham     AL         0
# 2                       Amridge University     AL         1
# 3      University of Alabama in Huntsville     AL         0
# 4                 Alabama State University     AL         0
# 5                The University of Alabama     AL         0
# 6        Central Alabama Community College     AL         0
# 7                  Athens State University     AL         0
# 8          Auburn University at Montgomery     AL         0
# 9                        Auburn University     AL         0
# 10             Birmingham Southern College     AL         1
# 11  Chattahoochee Valley Community College     AL         0
# 12               Concordia College Alabama     AL         1
# 13             South University-Montgomery     AL         0
# 14      Enterprise State Community College     AL         0

# %% [markdown]
# ## Lets examine how many groups (unique combinations of STABBR-RELAFFIL) exist

# %%
grouped.ngroups
# Out:
# 112

# %%
# We can look at group keys by chaining .groups.keys methods. 
# Lets look at first 6 group keys

groups = list(grouped.groups.keys())
groups[:6]
# Out:
# [('AK', 0), ('AK', 1), ('AL', 0), ('AL', 1), ('AR', 0), ('AR', 1)]

# %%
# We can get a single group using .get_group method

# %%
grouped.get_group(('FL', 1)).head()
# Out:
#                                     INSTNM           CITY STABBR  HBCU  \
# 712         The Baptist College of Florida     Graceville     FL   0.0
# 713                       Barry University          Miami     FL   0.0
# 714  Gooding Institute of Nurse Anesthesia    Panama City     FL   0.0
# 715             Bethune-Cookman University  Daytona Beach     FL   1.0
# 724             Johnson University Florida      Kissimmee     FL   0.0
#
#      MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  \
# 712      0.0        0.0         1     545.0     465.0           0.0
# 713      0.0        0.0         1     470.0     462.0           0.0
# 714      0.0        0.0         1       NaN       NaN           0.0
# 715      0.0        0.0         1     405.0     395.0           0.0
# 724      0.0        0.0         1     480.0     470.0           0.0
#
#             ...          UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  \
# ...

# %% [markdown]
# # CASE STUDY: Filtering for states with a minority majority

# %%
college = pd.read_csv('data/college.csv', index_col='INSTNM')
grouped = college.groupby('STABBR')
grouped.ngroups
# Out:
# 59

# %%
college[['UGDS', 'UGDS_WHITE']].head()
# Out:
#                                         UGDS  UGDS_WHITE
# INSTNM
# Alabama A & M University              4206.0      0.0333
# University of Alabama at Birmingham  11383.0      0.5922
# Amridge University                     291.0      0.2990
# University of Alabama in Huntsville   5451.0      0.6988
# Alabama State University              4811.0      0.0158

# %% [raw]
# We want to see which states have percentage of non-whites above a certain threshold.
# we define a function -- check_minority -- that has arguments 'df' and 'threshold'
#
# df is implicitly refering to te dataframe on which groupby is performed. It will just read dataframe name from groupby object on which we apply this function, we dont need to specify dataframe name explicitly
#
# threshold is the threshold percentage we want to check e.g 0.5 or 50%
#
# The check_minority function first calculates the number of minority student in each institute
# Then it sums it up over all institutions in that state. Repeats for all states.
#
# Similarly it calculates total number of students in each insitution and sums it over all insitutions in the state. repeats for all states
#
# Next calculates total percentage of minority students in  a state using state totals
#
# Finally, it returns rows with total minority percentage greater than our chosen threshold

# %%
def check_minority(df, threshold):
    minority_pct = 1 - df['UGDS_WHITE']
    total_minority = (df['UGDS'] * minority_pct).sum()
    total_ugds = df['UGDS'].sum()
    total_minority_pct = total_minority / total_ugds
    return total_minority_pct > threshold

# %%
college_filtered = grouped.filter(check_minority, threshold=.5)
college_filtered.head()
# Out:
#                                              CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Everest College-Phoenix                   Phoenix     AZ   0.0      0.0
# Collins College                           Phoenix     AZ   0.0      0.0
# Empire Beauty School-Paradise Valley      Phoenix     AZ   0.0      0.0
# Empire Beauty School-Tucson                Tucson     AZ   0.0      0.0
# Thunderbird School of Global Management  Glendale     AZ   0.0      0.0
#
#                                          WOMENONLY  RELAFFIL  SATVRMID  \
# INSTNM
# Everest College-Phoenix                        0.0         1       NaN
# Collins College                                0.0         0       NaN
# Empire Beauty School-Paradise Valley           0.0         1       NaN
# Empire Beauty School-Tucson                    0.0         0       NaN
# Thunderbird School of Global Management        0.0         0       NaN
#
#                                          SATMTMID  DISTANCEONLY    UGDS  \
# INSTNM
# ...

# %%
# total obs and cols in college dataframe

college.shape
# Out:
# (7535, 26)

# %%
# Obs and cols in dataframe with states having non-whites above 0.5 threshold
# States have multiple institutions where non-whites exceed threshold

college_filtered.shape
# Out:
# (3028, 26)

# %%
# Number of unique states where non-whites exceed threshold

college_filtered['STABBR'].nunique()
# Out:
# 20

# %% [markdown]
# ## Now try this for non-white threshold at 0.2

# %%
college_filtered_20 = grouped.filter(check_minority, threshold=.2)
college_filtered_20.shape
# Out:
# (7461, 26)

# %%
college_filtered_20['STABBR'].nunique()
# Out:
# 57

# %% [markdown]
# # Your Turn
# ## Try threshold of 0.7

# %% [markdown]
# # CASE STUDY: Transforming through a weight-loss

# %% [raw]
# Applying .agg method on groupby returns and aggregated data set eg sums of groups
# applying the .transform method on groupby returns transformed dataframe of same size as original
# with the result of transformation in a new col merged with original data bygroup

# %%
weight_loss = pd.read_csv('data/weight_loss.csv')
weight_loss.query('Month == "Jan"')
# Out:
#   Name Month    Week  Weight
# 0  Bob   Jan  Week 1     291
# 1  Amy   Jan  Week 1     197
# 2  Bob   Jan  Week 2     288
# 3  Amy   Jan  Week 2     189
# 4  Bob   Jan  Week 3     283
# 5  Amy   Jan  Week 3     189
# 6  Bob   Jan  Week 4     283
# 7  Amy   Jan  Week 4     190

# %%
# calculating weekly weight loss with ref to weight in week 1of each month

def find_perc_loss(s):
    return (s - s.iloc[0]) / s.iloc[0]

# %%
# Lets apply this function to look at Bob's weight loss in month of January
# first we use query to separate obs for Bob in jan, then apply function on variable 'weight'

bob_jan = weight_loss.query('Name=="Bob" and Month=="Jan"')
find_perc_loss(bob_jan['Weight'])
# Out:
# 0    0.000000
# 2   -0.010309
# 4   -0.027491
# 6   -0.027491
# Name: Weight, dtype: float64

# %%
# Use gruopby with grouping variables 'Name', 'Month', aggregation var 'Weight'
# We apply transform method on the groupby object using find_perc_loss function

pcnt_loss = weight_loss.groupby(['Name', 'Month'])['Weight'].transform(find_perc_loss)
pcnt_loss.head(8)
# Out:
# 0    0.000000
# 1    0.000000
# 2   -0.010309
# 3   -0.040609
# 4   -0.027491
# 5   -0.040609
# 6   -0.027491
# 7   -0.035533
# Name: Weight, dtype: float64

# %%
weight_loss['Perc Weight Loss'] = pcnt_loss.round(3)
weight_loss.query('Name=="Bob" and Month in ["Jan", "Feb"]')
# Out:
#    Name Month    Week  Weight  Perc Weight Loss
# 0   Bob   Jan  Week 1     291             0.000
# 2   Bob   Jan  Week 2     288            -0.010
# 4   Bob   Jan  Week 3     283            -0.027
# 6   Bob   Jan  Week 4     283            -0.027
# 8   Bob   Feb  Week 1     283             0.000
# 10  Bob   Feb  Week 2     275            -0.028
# 12  Bob   Feb  Week 3     268            -0.053
# 14  Bob   Feb  Week 4     268            -0.053

# %%
week4 = weight_loss.query('Week == "Week 4"')
week4
# Out:
#    Name Month    Week  Weight  Perc Weight Loss
# 6   Bob   Jan  Week 4     283            -0.027
# 7   Amy   Jan  Week 4     190            -0.036
# 14  Bob   Feb  Week 4     268            -0.053
# 15  Amy   Feb  Week 4     173            -0.089
# 22  Bob   Mar  Week 4     261            -0.026
# 23  Amy   Mar  Week 4     170            -0.017
# 30  Bob   Apr  Week 4     250            -0.042
# 31  Amy   Apr  Week 4     161            -0.053

# %%
winner = week4.pivot(index='Month', columns='Name', values='Perc Weight Loss')
winner
# Out:
# Name     Amy    Bob
# Month
# Apr   -0.053 -0.042
# Feb   -0.089 -0.053
# Jan   -0.036 -0.027
# Mar   -0.017 -0.026

# %%
winner['Winner'] = np.where(winner['Amy'] < winner['Bob'], 'Amy', 'Bob')
winner.style.highlight_min(axis=1)
# Out:
# <style  type="text/css" >
#     #T_0da2f4d2_b3cd_11e7_b9d4_b8e85647e68crow0_col0 {
#             background-color:  yellow;
#         }    #T_0da2f4d2_b3cd_11e7_b9d4_b8e85647e68crow1_col0 {
#             background-color:  yellow;
#         }    #T_0da2f4d2_b3cd_11e7_b9d4_b8e85647e68crow2_col0 {
#             background-color:  yellow;
#         }    #T_0da2f4d2_b3cd_11e7_b9d4_b8e85647e68crow3_col1 {
#             background-color:  yellow;
#         }</style>
# <table id="T_0da2f4d2_b3cd_11e7_b9d4_b8e85647e68c" >
# <thead>    <tr>
#         <th class="index_name level0" >Name</th>
#         <th class="col_heading level0 col0" >Amy</th>
#         <th class="col_heading level0 col1" >Bob</th>
#         <th class="col_heading level0 col2" >Winner</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Month</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
# ...

# %%
winner.Winner.value_counts()
# Out:
# Amy    3
# Bob    1
# Name: Winner, dtype: int64

# %% [markdown]
# # Calculating weighted mean SAT scores per state with apply

# %%
college = pd.read_csv('data/college.csv')
subset = ['UGDS', 'SATMTMID', 'SATVRMID']
college2 = college.dropna(subset=subset)
college.shape
# Out:
# (7535, 27)

# %%
college2.shape
# Out:
# (1184, 27)

# %%
def weighted_math_average(df):
    weighted_math = df['UGDS'] * df['SATMTMID']
    return int(weighted_math.sum() / df['UGDS'].sum())

# %%
college2.groupby('STABBR').apply(weighted_math_average).head()
# Out:
# STABBR
# AK    503
# AL    536
# AR    529
# AZ    569
# CA    564
# dtype: int64

# %%
college2.groupby('STABBR').agg(weighted_math_average).head()
# Out:
#         INSTNM  CITY  HBCU  MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# STABBR
# AK         503   503   503      503        503       503       503       503
# AL         536   536   536      536        536       536       536       536
# AR         529   529   529      529        529       529       529       529
# AZ         569   569   569      569        569       569       569       569
# CA         564   564   564      564        564       564       564       564
#
#         DISTANCEONLY  UGDS         ...          UGDS_2MOR  UGDS_NRA  \
# STABBR                             ...
# AK               503   503         ...                503       503
# AL               536   536         ...                536       536
# AR               529   529         ...                529       529
# AZ               569   569         ...                569       569
# CA               564   564         ...                564       564
#
# ...

# %%
college2.groupby('STABBR')['SATMTMID'].agg(weighted_math_average)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5126)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item (pandas/_libs/hashtable.c:14010)()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /Users/Ted/anaconda/lib/python3.6/site-packages/pandas/core/groupby.py in agg_series(self, obj, func)
#    2177         try:
# -> 2178             return self._aggregate_series_fast(obj, func)
#    2179         except Exception:
#
# /Users/Ted/anaconda/lib/python3.6/site-packages/pandas/core/groupby.py in _aggregate_series_fast(self, obj, func)
#    2197                                     dummy)
# ...

# %%
from collections import OrderedDict
def weighted_average(df):
    data = OrderedDict()
    weight_m = df['UGDS'] * df['SATMTMID']
    weight_v = df['UGDS'] * df['SATVRMID']

    data['weighted_math_avg'] = weight_m.sum() / df['UGDS'].sum()
    data['weighted_verbal_avg'] = weight_v.sum() / df['UGDS'].sum()
    data['math_avg'] = df['SATMTMID'].mean()
    data['verbal_avg'] = df['SATVRMID'].mean()
    data['count'] = len(df)
    return pd.Series(data, dtype='int')

college2.groupby('STABBR').apply(weighted_average).head(10)
# Out:
#         weighted_math_avg  weighted_verbal_avg  math_avg  verbal_avg  count
# STABBR
# AK                    503                  555       503         555      1
# AL                    536                  533       504         508     21
# AR                    529                  504       515         491     16
# AZ                    569                  557       536         538      6
# CA                    564                  539       562         549     72
# CO                    553                  547       540         537     14
# CT                    545                  533       522         517     14
# DC                    621                  623       588         589      6
# DE                    569                  553       495         486      3
# FL                    565                  565       521         529     38

# %%
from collections import OrderedDict
def weighted_average(df):
    data = OrderedDict()
    weight_m = df['UGDS'] * df['SATMTMID']
    weight_v = df['UGDS'] * df['SATVRMID']

    wm_avg = weight_m.sum() / df['UGDS'].sum()
    wv_avg = weight_v.sum() / df['UGDS'].sum()

    data['weighted_math_avg'] = wm_avg
    data['weighted_verbal_avg'] = wv_avg
    data['math_avg'] = df['SATMTMID'].mean()
    data['verbal_avg'] = df['SATVRMID'].mean()
    data['count'] = len(df)
    return pd.Series(data, dtype='int')

college2.groupby('STABBR').apply(weighted_average).head(10)
# Out:
#         weighted_math_avg  weighted_verbal_avg  math_avg  verbal_avg  count
# STABBR
# AK                    503                  555       503         555      1
# AL                    536                  533       504         508     21
# AR                    529                  504       515         491     16
# AZ                    569                  557       536         538      6
# CA                    564                  539       562         549     72
# CO                    553                  547       540         537     14
# CT                    545                  533       522         517     14
# DC                    621                  623       588         589      6
# DE                    569                  553       495         486      3
# FL                    565                  565       521         529     38

# %%
flights.sort_values(['MONTH', 'DAY', 'SCHED_DEP']) \
       .groupby(['AIRLINE', 'ORG_AIR']) \
       .apply(max_delay_streak) \
       .sort_values(['streak','MONTH','DAY'], ascending=[False, True, True]).head(10)
# Out:
#                             MONTH   DAY  streak
# AIRLINE ORG_AIR streak_row
# AA      DFW     first         2.0  26.0    38.0
#                 last          3.0   1.0    38.0
# MQ      ORD     first         1.0   6.0    28.0
#                 last          1.0  12.0    28.0
#         DFW     first         2.0  21.0    25.0
#                 last          2.0  26.0    25.0
# NK      ORD     first         6.0   7.0    15.0
#                 last          6.0  18.0    15.0
# DL      ATL     first        12.0  23.0    14.0
#                 last         12.0  24.0    14.0
