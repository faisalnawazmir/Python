# %% [markdown]
# # MODULE 4: SELECTING SUBSETS OF DATA

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Selecting DataFrame rows
#
# ## Using the location indexers *.iloc* and *.loc*  for making the selection

# %%
college = pd.read_csv('data/college.csv', index_col='INSTNM')
college.head()
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# Alabama State University             Montgomery     AL   1.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
# Amridge University                         0.0         1       NaN       NaN
# University of Alabama in Huntsville        0.0         0     595.0     590.0
# Alabama State University                   0.0         0     425.0     430.0
#
#                                      DISTANCEONLY     UGDS  \
# ...

# %%
pd.options.display.max_rows = 6

# %%
# For selecting subsets of data, we use two "indexers" .iloc and .loc that respectively select the subset of data based 
# on location. The .iloc selects subset based on *integer location* and .loc selects susbset of data based on label of 
# the index.

#Both .iloc and .loc indexers can select data from a dataFrame or a Series
# Both indexers can be used to select row or columns or both.
# We can pass scalers, lists, or slices (e.g. 5:10) to the indexers

# %%
# We can specify the integer location of the row with .iloc indexer
# We want 60th row

college.iloc[60]
# Out:
# CITY                  Anchorage
# STABBR                       AK
# HBCU                          0
#                         ...
# UG25ABV                  0.4386
# MD_EARN_WNE_P10           42500
# GRAD_DEBT_MDN_SUPP      19449.5
# Name: University of Alaska Anchorage, Length: 26, dtype: object

# %%
# Likewise, we can provide index label of the row we want and use .loc indexer
# We want the same row as above but now we provide the INSTNM variable's index label i.e. 'University of Alaska Anchorage'

college.loc['University of Alaska Anchorage']
# Out:
# CITY                  Anchorage
# STABBR                       AK
# HBCU                          0
#                         ...
# UG25ABV                  0.4386
# MD_EARN_WNE_P10           42500
# GRAD_DEBT_MDN_SUPP      19449.5
# Name: University of Alaska Anchorage, Length: 26, dtype: object

# %%
# We could also pass a list of rows to .iloc indexer 
# we want to subset (e.g 60th, 99th 3rd)
# Notice the use of double brackets to pass a list

college.iloc[[60, 99, 3]]
# Out:
#                                             CITY STABBR  HBCU  MENONLY  \
# INSTNM
# University of Alaska Anchorage         Anchorage     AK   0.0      0.0
# International Academy of Hair Design       Tempe     AZ   0.0      0.0
# University of Alabama in Huntsville   Huntsville     AL   0.0      0.0
#
#                                       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# University of Alaska Anchorage              0.0         0       NaN       NaN
# International Academy of Hair Design        0.0         0       NaN       NaN
# University of Alabama in Huntsville         0.0         0     595.0     590.0
#
#                                       DISTANCEONLY     UGDS  \
# INSTNM
# University of Alaska Anchorage                 0.0  12865.0
# International Academy of Hair Design           0.0    188.0
# University of Alabama in Huntsville            0.0   5451.0
#
#                                              ...          UGDS_2MOR  UGDS_NRA  \
# ...

# %%
# We can do the same things as above by passing the respective index labels and using .loc indexer
# Note we create a list of index labels first, and pass in to .loc indexer

labels = ['University of Alaska Anchorage',
          'International Academy of Hair Design',
          'University of Alabama in Huntsville']
college.loc[labels]
# Out:
#                                             CITY STABBR  HBCU  MENONLY  \
# INSTNM
# University of Alaska Anchorage         Anchorage     AK   0.0      0.0
# International Academy of Hair Design       Tempe     AZ   0.0      0.0
# University of Alabama in Huntsville   Huntsville     AL   0.0      0.0
#
#                                       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# University of Alaska Anchorage              0.0         0       NaN       NaN
# International Academy of Hair Design        0.0         0       NaN       NaN
# University of Alabama in Huntsville         0.0         0     595.0     590.0
#
#                                       DISTANCEONLY     UGDS  \
# INSTNM
# University of Alaska Anchorage                 0.0  12865.0
# International Academy of Hair Design           0.0    188.0
# University of Alabama in Huntsville            0.0   5451.0
#
#                                              ...          UGDS_2MOR  UGDS_NRA  \
# ...

# %%
# Alternatively we coudl pass a integer slice (e.g 99:102) to the .iloc indexer
# We want rows drom 99 to 102

college.iloc[99:102]
# Out:
#                                          CITY STABBR  HBCU  MENONLY  \
# INSTNM
# International Academy of Hair Design    Tempe     AZ   0.0      0.0
# GateWay Community College             Phoenix     AZ   0.0      0.0
# Mesa Community College                   Mesa     AZ   0.0      0.0
#
#                                       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# International Academy of Hair Design        0.0         0       NaN       NaN
# GateWay Community College                   0.0         0       NaN       NaN
# Mesa Community College                      0.0         0       NaN       NaN
#
#                                       DISTANCEONLY     UGDS  \
# INSTNM
# International Academy of Hair Design           0.0    188.0
# GateWay Community College                      0.0   5211.0
# Mesa Community College                         0.0  19055.0
#
#                                              ...          UGDS_2MOR  UGDS_NRA  \
# ...

# %%
# The label-based analogue to integer slice is to create a label slice
# we do this by specifying the start-label and the stop-label of the slice
# we use .loc indexer, and pass on to it the slice start:stop

start = 'International Academy of Hair Design'
stop = 'Mesa Community College'

college.loc[start:stop]
# Out:
#                                          CITY STABBR  HBCU  MENONLY  \
# INSTNM
# International Academy of Hair Design    Tempe     AZ   0.0      0.0
# GateWay Community College             Phoenix     AZ   0.0      0.0
# Mesa Community College                   Mesa     AZ   0.0      0.0
#
#                                       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# International Academy of Hair Design        0.0         0       NaN       NaN
# GateWay Community College                   0.0         0       NaN       NaN
# Mesa Community College                      0.0         0       NaN       NaN
#
#                                       DISTANCEONLY     UGDS  \
# INSTNM
# International Academy of Hair Design           0.0    188.0
# GateWay Community College                      0.0   5211.0
# Mesa Community College                         0.0  19055.0
#
#                                              ...          UGDS_2MOR  UGDS_NRA  \
# ...

# %% [markdown]
# # Selecting DataFrame rows and columns simultaneously

# %% [raw]
# ## We use:
# ## df.iloc[rows,  columns]
# ## df.loc[rows, columns]

# %%
# We import the college data set
# Subset first 3 row and first 4 columns, using .iloc indexer

college = pd.read_csv('data/college.csv', index_col='INSTNM')
college.iloc[:3, :4]
# Out:
#                                            CITY STABBR  HBCU  MENONLY
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0

# %%
# We want to make the same selction as above but now with labels
# We specify all labels upto 'Amridge University' (i.e. row 3), 
# and all columns upto 'MENONLY' (i.e. columns 4 ) 
# We get the same result as before

college.loc[:'Amridge University', :'MENONLY']
# Out:
#                                            CITY STABBR  HBCU  MENONLY
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0

# %%
# Select all rows and two different columns (4rth and 6th) with .iloc indexer

college.iloc[:, [4,6]].head()
# Out:
#                                      WOMENONLY  SATVRMID
# INSTNM
# Alabama A & M University                   0.0     424.0
# University of Alabama at Birmingham        0.0     570.0
# Amridge University                         0.0       NaN
# University of Alabama in Huntsville        0.0     595.0
# Alabama State University                   0.0     425.0

# %%
# can make the same selection as above but based on column labels and by using .loc indexer

college.loc[:, ['WOMENONLY', 'SATVRMID']]
# Out:
#                                                     WOMENONLY  SATVRMID
# INSTNM
# Alabama A & M University                                  0.0     424.0
# University of Alabama at Birmingham                       0.0     570.0
# Amridge University                                        0.0       NaN
# ...                                                       ...       ...
# National Personal Training Institute of Cleveland         NaN       NaN
# Bay Area Medical Academy - San Jose Satellite L...        NaN       NaN
# Excel Learning Center-San Antonio South                   NaN       NaN
#
# [7535 rows x 2 columns]

# %%
# We can even select disjoint row and columns simultaneously by passing two lists to .iloc indexer
# One list is for subsetting rows i.e. [100, 200] and the other for subsetting columns [7, 15]

college.iloc[[100, 200], [7, 15]]
# Out:
#                                        SATMTMID  UGDS_NHPI
# INSTNM
# GateWay Community College                   NaN     0.0029
# American Baptist Seminary of the West       NaN        NaN

# %%
# We can get the same result as above by passing lists of row- and columns-labels to .loc indexer

rows = ['GateWay Community College', 'American Baptist Seminary of the West']
columns = ['SATMTMID', 'UGDS_NHPI']

college.loc[rows, columns]
# Out:
#                                        SATMTMID  UGDS_NHPI
# INSTNM
# GateWay Community College                   NaN     0.0029
# American Baptist Seminary of the West       NaN        NaN

# %%
# Next we want to subset the 6th row and 4rth columns from the right
# So lets look at the first 6 rows and all columns
# Note: The 4rth column from the right is PCTFLOANS (scroll to the left and see)

college.head(6)
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# Alabama State University             Montgomery     AL   1.0      0.0
# The University of Alabama            Tuscaloosa     AL   0.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
# Amridge University                         0.0         1       NaN       NaN
# University of Alabama in Huntsville        0.0         0     595.0     590.0
# ...

# %%
# To select 6th row, set row index =5 
# To select 4rth column from the right column index = -4
# pass both integer locations to .iloc indexer

college.iloc[5, -4]
# Out:
# 0.401

# %%
# Same result is achieved by passing the respective row and column labels to .loc indexer

college.loc['The University of Alabama', 'PCTFLOAN']
# Out:
# 0.401

# %% [raw]
#   ***********************************************************************************************

# %% [markdown]
# # Selecting data with both integers and labels

# %% [raw]
# Here we will select rows and columns with slicing.Remember slicing depends on row/column location,
# which is based on simple counts (k = 1, 2, 3), e.g. 5th column, or 10th row
#
# Whereas, .iloc accepts as argument, the index value (I= 0,1,2,3), starts from zero
#
# So k = I + 1

# %%
college = pd.read_csv('data/college.csv', index_col='INSTNM')

# %%
# Let's look at columns of college dataFrame. Note 'CITY' is at index I=0 and UGDS_WHITE is at I=10
# and UGDS_UNKN is at I=18

college.columns
# Out:
# Index(['CITY', 'STABBR', 'HBCU', 'MENONLY', 'WOMENONLY', 'RELAFFIL',
#        'SATVRMID', 'SATMTMID', 'DISTANCEONLY', 'UGDS', 'UGDS_WHITE',
#        'UGDS_BLACK', 'UGDS_HISP', 'UGDS_ASIAN', 'UGDS_AIAN', 'UGDS_NHPI',
#        'UGDS_2MOR', 'UGDS_NRA', 'UGDS_UNKN', 'PPTUG_EF', 'CURROPER', 'PCTPELL',
#        'PCTFLOAN', 'UG25ABV', 'MD_EARN_WNE_P10', 'GRAD_DEBT_MDN_SUPP'],
#       dtype='object')

# %% [raw]
# We want to subset first 5 rows, and columns BETWEEN UGDS_WHITE and UGDS_UNKN
# We will subset a slice of the form [k1:k2], which will give us all columns BETWEEN column-k1 and columns-k2
#
# We will get values of index(I) of each column using .columns.get_loc method
# Next, we will find columns counts by k = I + 1
#
# Finally, we will define the slice as k1:k2, which will subset all columns BETWEEN the two limits,
# exclusive of both

# %%
#Note .columns.get_loc returns index I of the column.

col_start = college.columns.get_loc('UGDS_WHITE')
col_end = college.columns.get_loc('UGDS_UNKN') + 1

col_start, col_end
# Out:
# (10, 19)

# %%
# We want first 5 rows and every column between 10th and 19 columns, both exclusive

college.iloc[:5, col_start:col_end]
# Out:
#                                      UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Alabama A & M University                 0.0333      0.9353     0.0055
# University of Alabama at Birmingham      0.5922      0.2600     0.0283
# Amridge University                       0.2990      0.4192     0.0069
# University of Alabama in Huntsville      0.6988      0.1255     0.0382
# Alabama State University                 0.0158      0.9208     0.0121
#
#                                      UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Alabama A & M University                 0.0019     0.0024     0.0019
# University of Alabama at Birmingham      0.0518     0.0022     0.0007
# Amridge University                       0.0034     0.0000     0.0000
# University of Alabama in Huntsville      0.0376     0.0143     0.0002
# Alabama State University                 0.0019     0.0010     0.0006
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# ...

# %% [raw]
# A more direct approach is to simply use column names in the slice.
# In this case we will use .loc indexer
# And we will need row indices.
#
# Below we want to subset rows indexed 10 to 15
# We need to first get labels corresponding to I=10 and I=15
# We use .index method on dataFrame college to define the start and end rows

# %%
row_start = college.index[10]
row_end = college.index[15]
row_start, row_end
# Out:
# ('Birmingham Southern College', 'James H Faulkner State Community College')

# %%
college.loc[row_start:row_end, 'UGDS_WHITE':'UGDS_UNKN']
# Out:
#                                           UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Birmingham Southern College                   0.7983      0.1102     0.0195
# Chattahoochee Valley Community College        0.4661      0.4372     0.0492
# Concordia College Alabama                     0.0280      0.8758     0.0373
# South University-Montgomery                   0.3046      0.6054     0.0153
# Enterprise State Community College            0.6408      0.2435     0.0509
# James H Faulkner State Community College      0.6979      0.2259     0.0320
#
#                                           UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Birmingham Southern College                   0.0517     0.0102     0.0000
# Chattahoochee Valley Community College        0.0127     0.0023     0.0035
# Concordia College Alabama                     0.0093     0.0000     0.0000
# South University-Montgomery                   0.0153     0.0153     0.0096
# ...

# %% [markdown]
# # Scalar selection

# %% [raw]
# Scaler selection is reading a dataFrame value by a specifying a particular row and columns pair
# We can do this by using .loc indexer and passing on to it row and column names
#
# Below we specify a college name (row label) and a column name.

# %%
college = pd.read_csv('data/college.csv', index_col='INSTNM')
cn = 'Texas A & M University-College Station'
college.loc[cn, 'UGDS_WHITE']
# Out:
# 0.6609999999999999

# %%
# A better way is to use .at indexer when we have a scalar selection. It is faster

college.at[cn, 'UGDS_WHITE']
# Out:
# 0.6609999999999999

# %% [markdown]
# ## There's more...

# %%
state = college['STABBR']

# %%
# we can also use .iat indexer. Below we want teh state abbrevation (STABBR) at row index location 1000
state.iat[1000]
# Out:
# 'IL'

# %%
# Below we use .at indexer adn pass to it row label. We want state abbrevation at row label ='Stanford University'
state.at['Stanford University']
# Out:
# 'CA'

# %% [markdown]
# # Slicing Lexicographically

# %% [raw]
# We can specify a slice lexicographically, e.g. rows with index values between 'Sp' and 'Su'
# But rows must sorted first.

# %%
college = pd.read_csv('data/college.csv', index_col='INSTNM')
college = college.sort_index()

# %%
college.head()
# Out:
#                                                            CITY STABBR  HBCU  \
# INSTNM
# A & W Healthcare Educators                          New Orleans     LA   0.0
# A T Still University of Health Sciences              Kirksville     MO   0.0
# ABC Beauty Academy                                      Garland     TX   0.0
# ABC Beauty College Inc                              Arkadelphia     AR   0.0
# AI Miami International University of Art and De...        Miami     FL   0.0
#
#                                                     MENONLY  WOMENONLY  \
# INSTNM
# A & W Healthcare Educators                              0.0        0.0
# A T Still University of Health Sciences                 0.0        0.0
# ABC Beauty Academy                                      0.0        0.0
# ABC Beauty College Inc                                  0.0        0.0
# AI Miami International University of Art and De...      0.0        0.0
#
# ...

# %%
pd.options.display.max_rows = 6

# %%
college.loc['Sp':'Su']
# Out:
#                                                  CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Spa Tech Institute-Ipswich                    Ipswich     MA   0.0      0.0
# Spa Tech Institute-Plymouth                  Plymouth     MA   0.0      0.0
# Spa Tech Institute-Westboro                  Westboro     MA   0.0      0.0
# ...                                               ...    ...   ...      ...
# Stylemaster College of Hair Design           Longview     WA   0.0      0.0
# Styles and Profiles Beauty College             Selmer     TN   0.0      0.0
# Styletrends Barber and Hairstyling Academy  Rock Hill     SC   0.0      0.0
#
#                                             WOMENONLY  RELAFFIL  SATVRMID  \
# INSTNM
# Spa Tech Institute-Ipswich                        0.0         0       NaN
# Spa Tech Institute-Plymouth                       0.0         0       NaN
# Spa Tech Institute-Westboro                       0.0         0       NaN
# ...

# %%
# Another example

college.loc['B':'E']
# Out:
#                                                   CITY STABBR  HBCU  MENONLY  \
# INSTNM
# B M Spurr School of Practical Nursing        Glen Dale     WV   0.0      0.0
# BIR Training Center                            Chicago     IL   0.0      0.0
# BJ's Beauty & Barber College                    Auburn     WA   0.0      0.0
# ...                                                ...    ...   ...      ...
# Dutchess BOCES-Practical Nursing Program  Poughkeepsie     NY   0.0      0.0
# Dutchess Community College                Poughkeepsie     NY   0.0      0.0
# Dyersburg State Community College            Dyersburg     TN   0.0      0.0
#
#                                           WOMENONLY  RELAFFIL  SATVRMID  \
# INSTNM
# B M Spurr School of Practical Nursing           0.0         0       NaN
# BIR Training Center                             0.0         0       NaN
# BJ's Beauty & Barber College                    0.0         0       NaN
# ...
